# %%
# Pretrain the model
# !bash run.sh rope_pretrain
# Out:
# Starting Rope Pretrain: ~ 1 Hours
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# use device: 0
#
#   0%|          | 0/23 [00:00<?, ?it/s]
# epoch 1 iter 0: train loss 5.57822. lr 6.000000e-03:   0%|          | 0/23 [00:00<?, ?it/s]
# epoch 1 iter 0: train loss 5.57822. lr 6.000000e-03:   4%|4         | 1/23 [00:00<00:06,  3.24it/s]
# epoch 1 iter 1: train loss 5.16543. lr 5.999999e-03:   4%|4         | 1/23 [00:00<00:06,  3.24it/s]
# epoch 1 iter 1: train loss 5.16543. lr 5.999999e-03:   9%|8         | 2/23 [00:00<00:04,  5.13it/s]
# epoch 1 iter 2: train loss 3.68480. lr 5.999996e-03:   9%|8         | 2/23 [00:00<00:04,  5.13it/s]
# epoch 1 iter 2: train loss 3.68480. lr 5.999996e-03:  13%|#3        | 3/23 [00:00<00:03,  6.44it/s]
# epoch 1 iter 3: train loss 3.60212. lr 5.999992e-03:  13%|#3        | 3/23 [00:00<00:03,  6.44it/s]
# epoch 1 iter 3: train loss 3.60212. lr 5.999992e-03:  17%|#7        | 4/23 [00:00<00:02,  7.31it/s]
# ...

# %%
# Finetune the model
# !bash run.sh rope_finetune_with_pretrain
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# use device: 0
#
#   0%|          | 0/8 [00:00<?, ?it/s]
# epoch 1 iter 0: train loss 1.85570. lr 5.999999e-04:   0%|          | 0/8 [00:00<?, ?it/s]
# epoch 1 iter 0: train loss 1.85570. lr 5.999999e-04:  12%|#2        | 1/8 [00:00<00:03,  2.15it/s]
# epoch 1 iter 1: train loss 1.43638. lr 5.999992e-04:  12%|#2        | 1/8 [00:00<00:03,  2.15it/s]
# epoch 1 iter 1: train loss 1.43638. lr 5.999992e-04:  25%|##5       | 2/8 [00:00<00:01,  3.14it/s]
# epoch 1 iter 2: train loss 1.20151. lr 5.999980e-04:  25%|##5       | 2/8 [00:00<00:01,  3.14it/s]
# epoch 1 iter 2: train loss 1.20151. lr 5.999980e-04:  38%|###7      | 3/8 [00:00<00:01,  3.60it/s]
# epoch 1 iter 3: train loss 1.07556. lr 5.999962e-04:  38%|###7      | 3/8 [00:01<00:01,  3.60it/s]
# epoch 1 iter 3: train loss 1.07556. lr 5.999962e-04:  50%|#####     | 4/8 [00:01<00:01,  3.88it/s]
# ...

# %%
# Evaluate on the dev set; write to disk
# !bash run.sh rope_eval_dev_with_pretrain
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# Correct: 103.0 out of 500.0: 20.599999999999998%
# 0it [00:00, ?it/s]
# 1it [00:00,  4.93it/s]
# 3it [00:00,  8.31it/s]
# 4it [00:00,  8.72it/s]
# 6it [00:00, 10.73it/s]
# 8it [00:00, 12.15it/s]
# 10it [00:00, 13.03it/s]
# 12it [00:01, 14.02it/s]
# 14it [00:01, 14.08it/s]
# 16it [00:01, 14.67it/s]
# 18it [00:01, 15.07it/s]
# 20it [00:01, 11.91it/s]
# 22it [00:01, 10.10it/s]
# 24it [00:02,  9.18it/s]
# 26it [00:02,  8.49it/s]
# 27it [00:02,  8.38it/s]
# 28it [00:02,  8.19it/s]
# 29it [00:02,  7.92it/s]
# 30it [00:02,  7.82it/s]
# 31it [00:03,  7.76it/s]
# 32it [00:03,  7.64it/s]
# 33it [00:03,  7.68it/s]
# 34it [00:03,  7.56it/s]
# 35it [00:03,  7.53it/s]
# 36it [00:03,  7.62it/s]
# 37it [00:03,  7.50it/s]
# 38it [00:04,  7.53it/s]
# 39it [00:04,  7.52it/s]
# 40it [00:04,  7.55it/s]
# 41it [00:04,  7.48it/s]
# 42it [00:04,  7.49it/s]
# 43it [00:04,  7.48it/s]
# 44it [00:04,  7.51it/s]
# 45it [00:04,  7.56it/s]
# ...

# %%
# Evaluate on the test set; write to disk
# !bash run.sh rope_eval_test_with_pretrain
# Out:
# data has 418351 characters, 256 unique.
# number of parameters: 3323392
# !!! No ground truth is provided, this will be done on the autograder, returning (0,0)
# Predictions written to ./submission/rope.pretrain.test.predictions; no targets provided
# 0it [00:00, ?it/s]
# 1it [00:00,  4.81it/s]
# 3it [00:00,  8.80it/s]
# 5it [00:00, 10.72it/s]
# 7it [00:00, 12.31it/s]
# 9it [00:00, 11.51it/s]
# 11it [00:01, 10.87it/s]
# 13it [00:01, 11.30it/s]
# 15it [00:01, 11.57it/s]
# 17it [00:01, 10.15it/s]
# 19it [00:01,  8.84it/s]
# 20it [00:02,  8.43it/s]
# 21it [00:02,  8.17it/s]
# 22it [00:02,  7.97it/s]
# 23it [00:02,  7.79it/s]
# 24it [00:02,  7.71it/s]
# 25it [00:02,  7.54it/s]
# 26it [00:02,  7.43it/s]
# 27it [00:03,  7.34it/s]
# 28it [00:03,  7.24it/s]
# 29it [00:03,  7.19it/s]
# 30it [00:03,  7.16it/s]
# 31it [00:03,  7.10it/s]
# 32it [00:03,  7.08it/s]
# 33it [00:03,  7.09it/s]
# 34it [00:04,  7.21it/s]
# 35it [00:04,  7.24it/s]
# 36it [00:04,  7.27it/s]
# 37it [00:04,  7.33it/s]
# ...
